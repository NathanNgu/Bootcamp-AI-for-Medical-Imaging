# %% [markdown]
# # Module 1: Data Science
#
# Welcome to the AI Bootcamp. The goal of this bootcamp is to introduce you as well as evaluate your knowledge on some of the basic concepts in the field of Artificial Intelligence. We will use the flipped classroom approach in this bootcamp where you will be introduced to different concepts with the help of assignments and projects.
#
# In the first module, we will look at working with tabular data using the [Wisconsin breast cancer dataset](https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data) as an example.

# %% [markdown]
# ## 1.1 Data exploration
# **Pandas** is one of the most popular libraries in the field of data science. It is an open source library build on top of the Python programming language and provides flexible and easy-to-use functions for data analysis and manipulation.
#
# *Here is your first assignment for this module. Your responses should be added to the code block following this text block. Feel free to refer to the pandas documentation and/or google solutions to these questions.*
#
# **Assignment 1.1**
#
# *   We have shared a [folder](https://drive.google.com/drive/folders/1JPoMMHG7XdHZSsNs3BaBSMwLn5vFTerh?usp=sharing) with you. Click on this [link](https://drive.google.com/drive/folders/1JPoMMHG7XdHZSsNs3BaBSMwLn5vFTerh?usp=sharing) and create a shortcut to this folder in your drive. See the figure below:
# ![Snip20220811_1.png](data:image/png;base64,...)
# *   Mount google drive to your workspace
# *   Navigate to the shortcut you created in your drive.
# *   List the files/sub-folders in this folder.
# *   Load the data csv file using pandas
# *   Visualize first 5 rows of your dataset
# *   List the columns/features present in your dataset
# *   Remove the following feature/column from your dataframe: id
# *   Create a new dataframe (df1) with the following features: radius_mean and area_mean
# *   Create a new dataframe (df2) with the following features: diagnosis
# *   Combine the dataframes, df1 and df2 to create a new dataframe, df12
# *   Create a new dataframe with the subset of rows with radius_mean >= 15
# *   Create a matrix (M1) containing only the numerical values from df1
# *   Transform each column of M1 to have values between 0 and 1 and save the new matrix to M2
# *   Create a new dataframe, df3 from df1 where each feature column is normalized between 0 and 1.
# *   Write each of the dataframes created above to different csv files
#
# **Useful links for this assignment**
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html
# 2. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html
# 3. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.filter.html
# 4. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
# 5. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html

# %%
import pandas as pd
import os

# Assignment 1.1

# Mount Google Drive to your workspace
from google.colab import drive
drive.mount('/content/drive')
# Navigate to the shared folder
# Note: I renamed the shared folder to: Data_UM2ii_Bootcamp
os.chdir('/content/drive/MyDrive/Data_UM2ii_Bootcamp')
# Display the contents in the shared folder
print('This folder contains the following files and sub-folders:',os.listdir())

# Load the csv file
df = pd.read_csv('data.csv')

# Visualize first 5 rows of your dataset

# List the columns/features present in your dataset

# Remove the following feature/column from your dataframe: id

# Create a new dataframe (df1) with the following features: radius_mean and area_mean

# Create a new dataframe (df2) with the following features: diagnosis

# Combine the dataframes, df1 and df2 to create a new dataframe, df12

# Create a new dataframe with the subset of rows with radius_mean >= 15

# Create a matrix (M1) containing only the numerical values from df1

# Transform each column of M1 to have values between 0 and 1 and save the new matrix to M2

# Create a new dataframe, df3 from df1 where each feature column is normalized between 0 and 1.

# Write each of the dataframes created above to different csv files

# %% [markdown]
# ## 1.2 Data statistics
#
# **Assignment 1.2**
#
# *   Calculate mean, median, standard deviation, max, min, and range for each feature in the dataset.
# *   Count the number of benign and malignant samples in your dataset.
# *   Calculate **groupwise** (for the two groups: B and M) mean, median, standard deviation, max, min, and range for each feature in the dataset. (**Hint: Use pandas.Dataframe.groupby**)
#
# *   Calculate [unpaired ttest](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind_from_stats.html#scipy.stats.ttest_ind_from_stats) for each feature in the dataset
# *   Calculate [Wilkoxon rank-sum test](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ranksums.html#scipy.stats.ranksums) for each feature in the dataset
# *   What is the difference between the two tests (ttest and rank-sum)?
# *   Calculate the correlation coefficient between radius_mean and area_mean. Which correlation coefficient did you use? Why?
#
# **Useful links:**
# 1. https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html
# 2. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind_from_stats.html#scipy.stats.ttest_ind_from_stats
# 3. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ranksums.html#scipy.stats.ranksums

# %%
# Assignment 1.2

# Calculate mean, median, standard deviation, max, min, and range for each feature in the dataset.

# Count the number of benign and malignant samples in your dataset.

# Calculate groupwise (for the two groups: B and M) mean, median, standard deviation, max, min, and range for each feature in the dataset. (Hint: Use pandas.Dataframe.groupby)

# Calculate unpaired ttest for each feature in the dataset

# Calculate Wilkoxon rank-sum test for each feature in the dataset

# Calculate the correlation coefficient between radius_mean and area_mean.

# %% [markdown]
# ## 1.3 Data visualization
#
# **Assignment 1.3**
#
# *Hint: Use seaborn*
#
# *   Create histogram to visualize the distribution of radius_mean.
# *   Use scatterplot to visualize the relationship between radius_mean and area_mean
# *   Color code the above scatterplot based on the diagnosis groups, B and M
# *   Create a "pairplot" visualization to visualize relationships between radius_mean, area_mean, and smoothness features.
# *   Create violin, box, and bar plots to visualize the distribution of  area_mean and radius_mean across the two groups, B and M. Make sure to use color codes to reflect different groups.
# *   Compute pairwise correlation between each feature and visualize the values on a heatmap. Color code the heatmap to reflect the different correlation coefficient value.
#
# **Useful links:**
# 1. https://seaborn.pydata.org/tutorial/function_overview.html

# %%
# Assignment 1.3

# Create histogram to visualize the distribution of radius_mean.

# Use scatterplot to visualize the relationship between radius_mean and area_mean

# Color code the above scatterplot based on the diagnosis groups, B and M

# Create a multi-scatterplot visualization to visualize relationships between radius_mean, area_mean, and smoothness features.

# Create violin, box, and bar plots to visualize the distribution of area_mean and radius_mean across the two groups, B and M. Make sure to use color codes to reflect different groups.

# Compute pairwise correlation between each feature and visualize the values on a heatmap. Color code the heatmap to reflect the different correlation coefficient value.
