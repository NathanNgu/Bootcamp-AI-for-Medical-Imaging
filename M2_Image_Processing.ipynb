# %% [markdown]
# # Module 2: Images
#
# In this module, we will look at working with medical images. We will use the following images throughout this module: **[Knee MRI image in the dicom format](https://drive.google.com/file/d/18szKEsfWko9PnuG__SuAVNQLhTVv-1Ha/view?usp=sharing)**

# %% [markdown]
# ## 2.1 DICOM
#
# **Assignment 2.1**
#
# *   What is DICOM? Why is it used?
# *   Install the pydicom library in this workspace
# *   Upload the dicom file to this workspace
# *   Read the dicom data using pydicom
# *   Extract the image information and display the image. **Note: Make sure the image is displayed in gray colorscale**
# *   Extract the following information from the dicom data
#   *   Patient Name
#   *   Patient Age
#   *   Patient Sex
#   *   Series Description: What kind of MRI image is this?
#   *   Slice location: This helps you organize/sort the slices in an acquisition
# *   Change the above mentioned dicom tags (to random values) and save the updated dicom data to a new file. Load the new dicom file and print these tags to make sure they have been changed.
# *   Save the image information in the dicom to a png file format.
# *   Load and display the saved png image.

# %%
# Assignment 2.1

# install pydicom

# import pydicom

# read a the dicom file

# display the image

# extract the meta data

# randomly modify the dicom data

# save the image to a png

# load and display the png

# %% [markdown]
# ## 2.2 Exploration
#
# **Assignment 2.2**
#
# *Use the image information extracted in the Assignment 1.1 for the following tasks*
#
# *   Calculate size of the image (height and width)
# *   Find the max, min, mean, median, and standard deviation of the intensity values in the image
# *   Visualize the distribution of image intensities using a histogram
# *   Load the saved png image and extract its statistics. Do you notice any difference?

# %%
# Assignment 2.2

# Image size

# Image Stats

# Histogram visualization

# Png Stats

# %% [markdown]
# ## 2.3 Processing
#
# **Assignment 2.3**
#
# *Use the image information extracted in the Assignment 1.1 for the following tasks.*
#
# ***Useful libraries for this assignment: opencv, scipy, matplotlib***
#
# *   Normalize the image intensities to have values between 0 and 1.
# *   Perform histogram equalization.
#    *   Visualize the distribution of image intensities (before and after histogram equalization).
#    *   Display both the images.
# *   Threshold the normalized image at 0.25, 0.5, and 0.75. Visualize all three b/w images.
# *   Perform the following operations. Display the resultant images after each operation.
#   *  Scale the image to half its size.
#   *  Rotate the image by 90 degrees
#   *  Crop the image from the center such that the new image should have dimensions of 64x64

# %%
# Assignment 2.3

# Normalize the image intensities to have values between 0 and 1.

# Perform histogram equalization

# Threshold the normalized image at 0.25, 0.5, and 0.75. Visualize all three b/w images.

# Scaling

# Rotation

# Cropping

# %% [markdown]
# ## 2.4 ROIs
#
# **Assignment 2.4**
#
# *Use the image information extracted in the Assignment 1.1 for the following tasks.*
#
# ***Useful libraries for this assignment: opencv, scipy, matplotlib***
#
# *   Draw a rectangle somewhere on the image and perform the following tasks. **Note: you do not need to draw the rectangle interactively using your mouse pointer. You just need to draw the rectangle by mentioning its coordinates (Hint: cv2.rectangle() to draw the rectangle)**
#   *   What is the width and height of the rectangle.
#   *   Display the rectangular box overlaid on the image.
#   *   Crop the image section inside the rectangle and display the new image.
#   *   Create a mask image of the same size as the original image such that the the region inside the rectangle is white (1) and rest of the image is black (0). Display the resultant image.
#   *   Preserve the information (pixel intensities) within the rectangle while zeroing out rest of the image. Display the resultant image.

# %%
# Assignment 2.4
